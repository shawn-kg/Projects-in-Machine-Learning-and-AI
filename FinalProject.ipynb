# %% [markdown]
# <a href="https://colab.research.google.com/github/shawn-kg/Projects-in-Machine-Learning-and-AI/blob/main/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Decision Tree Implementation

# %%
import pandas as pd
import numpy as np
import math


from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics # Import scikit-learn metrics module for accuracy calculation
 
# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from sklearn import tree
from sklearn.tree import export_text
import graphviz

col_names = ['target', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst' ]
cancer_data = pd.read_csv('drive/MyDrive/data_augmented.csv', header=None, names=col_names)
randomized_data = cancer_data.reindex(np.random.permutation(cancer_data.index))

feature_cols = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst']
X = randomized_data[feature_cols]
y = randomized_data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=1) # 70% training and 30% test

# Initialize our decision tree object
classification_tree = tree.DecisionTreeClassifier()
classification_tree = classification_tree.fit(X_train, y_train)

y_pred = classification_tree.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test,y_pred))
print("Recall:",metrics.recall_score(y_test,y_pred))

dot_data = tree.export_graphviz(classification_tree, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("dec_tree1")

# Initialize our decision tree object
classification_tree = tree.DecisionTreeClassifier()

classification_tree.max_depth = 4
# Train our decision tree (tree induction + pruning)
classification_tree = classification_tree.fit(X_train, y_train)

y_pred = classification_tree.predict(X_test)

dot_data = tree.export_graphviz(classification_tree, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("dec_tree2") 

print("\nAccuracy  with depth of 4:",metrics.accuracy_score(y_test, y_pred))
print("Precision with depth of 4:",metrics.precision_score(y_test,y_pred))
print("Recall with depth of 4:",metrics.recall_score(y_test,y_pred))
# Out:
# Accuracy: 0.935672514619883
# Precision: 0.972972972972973
# Recall: 0.9310344827586207
#
# Accuracy  with depth of 4: 0.9298245614035088
# Precision with depth of 4: 0.9727272727272728
# Recall with depth of 4: 0.9224137931034483

# %% [markdown]
# #Random Forest and Gradient Booster Optimizations

# %%
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

model = RandomForestClassifier(max_depth=5)
cv = RepeatedStratifiedKFold(n_splits=10,n_repeats=3,random_state=1)
n_scores = cross_val_score(model, X, y, scoring= 'accuracy', cv=cv, n_jobs=-1,error_score='raise')
o_scores = cross_val_score(model, X, y, scoring= 'precision', cv=cv, n_jobs=-1, error_score='raise')
p_scores = cross_val_score(model, X, y, scoring = 'recall', cv=cv, n_jobs=-1, error_score='raise')

print('Random Forest Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
print('Random Forest Precision: %.3f (%.3f)' % (mean(o_scores), std(n_scores)))
print('Random Forest Recall: %.3f (%.3f)' % (mean(p_scores), std(p_scores)))



#Boosting Gradient Boost Algorithm
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=5, random_state=0)
q_scores = cross_val_score(clf,X,y,scoring= 'accuracy',cv=cv,n_jobs=-1,error_score='raise')
r_scores = cross_val_score(clf,X,y,scoring= 'precision',cv=cv,n_jobs=-1,error_score='raise')
s_scores = cross_val_score(clf,X,y,scoring = 'recall', cv = cv,n_jobs=-1,error_score='raise')

print('\nGradient Boosting Classifier Accuracy: %.3f (%.3f)' % (mean(q_scores), std(q_scores)))
print('Gradient Boosting Classifier Precision: %.3f (%.3f)' % (mean(r_scores), std(r_scores)))
print('Gradient Boosting Classifier Recall: %.3f (%.3f)' % (mean(s_scores), std(s_scores)))
# Out:
# Random Forest Accuracy: 0.957 (0.024)
# Random Forest Precision: 0.962 (0.024)
# Random Forest Recall: 0.979 (0.024)
#
# Gradient Boosting Classifier Accuracy: 0.958 (0.025)
# Gradient Boosting Classifier Precision: 0.959 (0.033)
# Gradient Boosting Classifier Recall: 0.976 (0.026)

# %% [markdown]
# #Deep Neural Network

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential

X_train, X_dev, y_train, y_dev = train_test_split(X_train, y_train, test_size=0.25, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
n_features = X_train.shape[1]

# create the model
model = Sequential()
model.add(Dense(6, activation='relu', kernel_initializer='he_normal', input_shape=(n_features,)))
model.add(Dense(1,activation = 'sigmoid'))
opt = tf.keras.optimizers.RMSprop(learning_rate=0.01, momentum=0.9)
model.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# fitting the model
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=0)
# evaluate
loss, acc, prec, recall = model.evaluate(X_dev,y_dev,verbose=0)
print("Loss: ", loss, "Acc: ", acc, "Precision: ", prec, "Recall: ", recall)

test_loss, test_acc, test_prec, test_recall = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss: ", test_loss, "Test Accuracy: ", test_acc, "Test Precision: ", test_prec, "Test Recall: ", test_recall)
# Out:
# (298, 30) (171, 30) (298,) (171,)
# Loss:  0.16466128826141357 Acc:  0.9599999785423279 Precision:  0.95652174949646 Recall:  0.9850746393203735
# Test Loss:  0.13441075384616852 Test Accuracy:  0.9590643048286438 Test Precision:  0.9430894255638123 Test Recall:  1.0

# %% [markdown]
# #Deep Learning 2.0

# %%
model2 = Sequential()
# first hidden layer
model2.add(Dense(units=9,kernel_initializer='he_uniform',activation='relu',input_shape=(n_features,)))
# second hidden layer
model2.add(Dense(units=9,kernel_initializer='he_uniform',activation='relu'))
#output layer
model2.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))

model2.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

model2.fit(X_train, y_train, batch_size = 100, epochs = 150)

loss, acc, prec, recall = model.evaluate(X_dev,y_dev,verbose=0)

print("Loss: ", loss, "Acc: ", acc, "Precision: ", prec, "Recall: ", recall)

test_loss, test_acc, test_prec, test_recall = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss: ", test_loss, "Test Accuracy: ", test_acc, "Test Precision: ", test_prec, "Test Recall: ", test_recall)
# Out:
# Epoch 1/150
# 3/3 [==============================] - 1s 5ms/step - loss: 84.7269 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 2/150
# 3/3 [==============================] - 0s 5ms/step - loss: 81.1666 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 3/150
# 3/3 [==============================] - 0s 5ms/step - loss: 77.7332 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 4/150
# 3/3 [==============================] - 0s 5ms/step - loss: 74.4243 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 5/150
# 3/3 [==============================] - 0s 5ms/step - loss: 71.1187 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 6/150
# 3/3 [==============================] - 0s 5ms/step - loss: 68.1368 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 7/150
# 3/3 [==============================] - 0s 5ms/step - loss: 64.9829 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 8/150
# 3/3 [==============================] - 0s 4ms/step - loss: 62.1128 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 9/150
# 3/3 [==============================] - 0s 5ms/step - loss: 59.3249 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 10/150
# 3/3 [==============================] - 0s 5ms/step - loss: 56.5157 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch 11/150
# 3/3 [==============================] - 0s 6ms/step - loss: 53.8802 - accuracy: 0.4161 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Epoch
- accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 51/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6789 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 52/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6789 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 53/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6788 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 54/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6786 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 55/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6786 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 56/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6784 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 57/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6784 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 58/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6782 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 59/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6782 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 60/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6781 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 61/150
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6780 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 62/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6778 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 63/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6778 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 64/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6777 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 65/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6777 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 66/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6776 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 67/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6776 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 68/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6775 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 69/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6774 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 70/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6774 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 71/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6773 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 72/150
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6773 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 73/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6773 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 74/150
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6772 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 75/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6773 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 76/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6772 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 77/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6772 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 78/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6771 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 79/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6771 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 80/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6771 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 81/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6770 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 82/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6770 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 83/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6770 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 84/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6770 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 85/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6770 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 86/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6770 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 87/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6770 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 88/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 89/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 90/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 91/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 92/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 93/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 94/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 95/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 96/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 97/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 98/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 99/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 100/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 101/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 102/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 103/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 104/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 105/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 106/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 107/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 108/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 109/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 110/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 111/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 112/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 113/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 114/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6768 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 115/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 116/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 117/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 118/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 119/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 120/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 121/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 122/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 123/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 124/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 125/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 126/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 127/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 128/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 129/150
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 130/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 131/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 132/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 133/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 134/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 135/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 136/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 137/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 138/150
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 139/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 140/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6767 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 141/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 142/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 143/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 144/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 145/150
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 146/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 147/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 148/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 149/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Epoch 150/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6766 - accuracy: 0.5872 - precision_2: 0.5859 - recall_2: 1.0000
# Loss:  0.16466128826141357 Acc:  0.9599999785423279 Precision:  0.95652174949646 Recall:  0.9850746393203735
# Test Loss:  0.13441075384616852 Test Accuracy:  0.9590643048286438 Test Precision:  0.9430894255638123 Test Recall:  1.0

# %% [markdown]
# # Hyperparameter Tuning

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 5.9 MB/s

# %%
import kerastuner as kt
import tensorflow as tf

def build_model(hp):
  model = Sequential()

  hp_units = hp.Int('units', min_value = 5, max_value = 21, step =2)
  
  model.add(Dense(units = hp_units, activation = 'relu', kernel_initializer='he_normal', input_shape=(n_features,)))

  # Tune whether to use dropout.
  if hp.Boolean("dropout"):
    model.add(layers.Dropout(rate=0.25))
  
  model.add(Dense(1,activation = 'sigmoid'))

  hp_learning_rate = hp.Choice('learning_rate', values = [1e-2, 1e-3,1e-4])
  opt = tf.keras.optimizers.RMSprop(learning_rate=hp_learning_rate, momentum=0.9)
  model.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
  
  return model

tuner = kt.RandomSearch(build_model,
                        objective = 'val_accuracy', 
                        max_trials = 20,
                        directory = 'random_search_starter',
                        project_name = 'intro_to_kt') 
                     
tuner.search(X_train, y_train, epochs = 100, validation_data = (X_dev, y_dev))

best_model = tuner.get_best_models(1)[0]

best_hyperparameters = tuner.get_best_hyperparameters(1)[0] 

test_loss, test_acc, test_prec, test_recall = model.evaluate(X_test, y_test, verbose=0)
print("Test Loss: ", test_loss, "Test Accuracy: ", test_acc, "Test Precision: ", test_prec, "Test Recall: ", test_recall)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project random_search_starter/intro_to_kt/oracle.json
# INFO:tensorflow:Reloading Tuner from random_search_starter/intro_to_kt/tuner0.json
# INFO:tensorflow:Oracle triggered exit
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.rho
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Test Loss:  0.13441075384616852 Test Accuracy:  0.9590643048286438 Test Precision:  0.9430894255638123 Test Recall:  1.0
